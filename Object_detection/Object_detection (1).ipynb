# %%
# checking the GPU 
! nvidia-smi
# Out:
# Tue Jul 12 08:27:55 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0    34W / 250W |   1089MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# installing the dependency
# !pip install torch==1.8.2 torchvision==0.9.2 torchaudio===0.8.2 --extra-index-url https://download.pytorch.org/whl/lts/1.8/cu111
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/lts/1.8/cu111
# ...

# %%
# cloning the repo
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
'''
 # !cd /content/yolov5
'''
# Out:
# '\n !cd /content/yolov5\n'

# %%
# insatlling the requirements
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# importing the library
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # Loading Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-7-12 Python-3.7.13 torch-1.8.2+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): Model(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
img = 'https://ultralytics.com/images/zidane.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 277.3ms pre-process, 15.2ms inference, 2.2ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
np.squeeze(results.render()).shape
# Out:
# (720, 1280, 3)

# %%
plt.imshow(np.squeeze(results.render()))

# %%
img2 ='https://www.newshub.co.nz/home/new-zealand/2016/11/crash-halts-traffic-on-auckland-motorway/_jcr_content/par/image.dynimg.1280.q75.jpg/v1/cars_motorway_traffic_tiltshift-1200.jpg'

# %%
results2 = model(img2)
results2.print()
# Out:
# image 1/1: 719x1280 20 cars, 1 motorcycle, 1 bus, 1 truck
# Speed: 730.3ms pre-process, 12.9ms inference, 1.9ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results2.render()))
plt.show()

# %%
plt.imshow(np.squeeze(results2.render()))

# %%
img3 = 'https://media.wired.com/photos/61f1edf3f355cd4b798a011c/master/pass/Business_Traffic%20Jam-1312394408.jpg'

# %%
results3 = model(img3)
results3.print()
# Out:
# image 1/1: 1800x2400 23 cars, 7 trucks
# Speed: 267.3ms pre-process, 21.1ms inference, 1.9ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results3.render()))
plt.show()

# %%
img4 = 'https://st1.bgr.in/wp-content/uploads/2015/05/google-map-traffic-update1.jpg'
results4 = model(img4)
results4.print()
# Out:
# image 1/1: 456x805 4 persons, 29 cars, 1 motorcycle, 3 buss
# Speed: 1517.1ms pre-process, 14.2ms inference, 1.9ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results4.render()))
plt.show()
